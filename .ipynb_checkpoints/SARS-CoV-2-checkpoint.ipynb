# %%
def parse_fasta(fasta_file):
    sequence = ''
    with open(fasta_file) as f:
        for line in f:
            if not line.startswith(">"):
                sequence += line.strip()
                
    return sequence

# %%
def get_genes(seq):
    first_start = sequence.index("ATG") # stores position of first START codon
    stop_codons = ['TAG', 'TAA', 'TGA']
    for i in range(first_start, len(seq), 3):
        codon = seq[i:i+3]
        if codon == 'ATG':
            print("START", codon, "index =", i)
        #if codon in stop_codons:
        #    print("STOP", codon, "index =", i)

# %%
sequence = parse_fasta("sars_cov2.fasta")
get_genes(sequence)
# Out:
# START ATG index = 106
# START ATG index = 265
# START ATG index = 517
# START ATG index = 784
# START ATG index = 1153
# START ATG index = 1207
# START ATG index = 1225
# START ATG index = 2014
# START ATG index = 2017
# START ATG index = 2056
# START ATG index = 2455
# START ATG index = 2629
# START ATG index = 2680
# START ATG index = 2683
# START ATG index = 2968
# START ATG index = 3022
# START ATG index = 3304
# START ATG index = 3511
# START ATG index = 3841
# START ATG index = 4198
# START ATG index = 4396
# START ATG index = 4429
# START ATG index = 4606
# START ATG index = 4660
# START ATG index = 5020
# START ATG index = 5026
# START ATG index = 5203
# START ATG index = 5458
# START ATG index = 5569
# START ATG index = 5575
# START ATG index = 5680
# START ATG index = 5683
# START ATG index = 6370
# START ATG index = 6550
# START ATG index = 6769
# START ATG index = 6844
# START ATG index = 7024
# START ATG index = 7039
# START ATG index = 7303
# START ATG index = 7357
# START ATG index = 7384
# START ATG index = 7402
# START ATG index = 7411
# START ATG index = 7492
# START ATG index = 7495
# START ATG index = 7957
# START ATG index = 8032
# START ATG index = 8080
# START ATG index = 8284
# START ATG index = 8311
# START ATG index = 8419
# START ATG index = 8650
# START ATG index = 9133
# START ATG index = 9352
# START ATG index = 9457
# START ATG index = 9523
# START ATG index = 9649
# START ATG index = 9655
# START ATG index = 9829
# START ATG index = 9925
# START ATG index = 10069
# START ATG index = 10102
# START ATG index = 10198
# START ATG index = 10297
# START ATG index = 10441
# START ATG index = 10537
# START ATG index = 10546
# START ATG index = 10756
# START ATG index = 10843
# START ATG index = 10879
# START ATG index = 11110
# START ATG index = 11125
# START ATG index = 11140
# START ATG index = 11143
# START ATG index = 11218
# START ATG index = 11227
# START ATG index = 11245
# START ATG index = 11254
# START ATG index = 11269
# START ATG index = 11314
# START ATG index = 11347
# START ATG index = 11398
# START ATG index = 11461
# START ATG index = 11518
# START ATG index = 11545
# START ATG index = 11602
# START ATG index = 11731
# START ATG index = 11848
# START ATG index = 11995
# START ATG index = 12025
# START ATG index = 12064
# START ATG index = 12253
# START ATG index = 12274
# START ATG index = 12289
# START ATG index = 12298
# START ATG index = 12349
# START ATG index = 12358
# START ATG index = 12370
# START ATG index = 12475
# START ATG index = 12610
# START ATG index = 12718
# START ATG index = 12985
# START ATG index = 13153
# START ATG index = 13210
# START ATG index = 13387
# START ATG index = 13432
# START ATG index = 13525
# START ATG index = 13555
# START ATG index = 13624
# START ATG index = 13684
# START ATG index = 13735
# START ATG index = 13825
# START ATG index = 13843
# START ATG index = 13897
# START ATG index = 13900
# START ATG index = 13927
# START ATG index = 14020
# START ATG index = 14032
# START ATG index = 14077
# START ATG index = 14089
# START ATG index = 14206
# START ATG index = 14257
# START ATG index = 14347
# START ATG index = 14380
# START ATG index = 14446
# START ATG index = 14512
# START ATG index = 14560
# START ATG index = 14650
# START ATG index = 14698
# START ATG index = 14773
# START ATG index = 14779
# START ATG index = 14797
# START ATG index = 14890
# START ATG index = 14905
# START ATG index = 14986
# START ATG index = 15001
# START ATG index = 15013
# START ATG index = 15040
# START ATG index = 15076
# START ATG index = 15223
# START ATG index = 15262
# START ATG index = 15409
# START ATG index = 15460
# START ATG index = 15490
# START ATG index = 15505
# START ATG index = 15547
# START ATG index = 15553
# START ATG index = 15571
# START ATG index = 15595
# START ATG index = 15622
# START ATG index = 15646
# START ATG index = 15667
# START ATG index = 15721
# START ATG index = 15748
# START ATG index = 15811
# START ATG index = 15868
# START ATG index = 15910
# START ATG index = 15916
# START ATG index = 15973
# START ATG index = 15991
# START ATG index = 16033
# START ATG index = 16069
# START ATG index = 16075
# START ATG index = 16114
# START ATG index = 16117
# START ATG index = 16165
# START ATG index = 16201
# START ATG index = 16333
# START ATG index = 16378
# START ATG index = 16387
# START ATG index = 16402
# START ATG index = 16411
# START ATG index = 16492
# START ATG index = 16540
# START ATG index = 16555
# START ATG index = 16582
# START ATG index = 16681
# START ATG index = 16774
# START ATG index = 16849
# START ATG index = 16855
# START ATG index = 16894
# START ATG index = 16972
# START ATG index = 17014
# START ATG index = 17029
# START ATG index = 17167
# START ATG index = 17179
# START ATG index = 17299
# START ATG index = 17317
# START ATG index = 17356
# START ATG index = 17380
# START ATG index = 17398
# START ATG index = 17422
# START ATG index = 17605
# START ATG index = 17680
# START ATG index = 17683
# START ATG index = 17791
# START ATG index = 17857
# START ATG index = 17863
# START ATG index = 17905
# START ATG index = 17920
# START ATG index = 17980
# START ATG index = 18022
# START ATG index = 18046
# START ATG index = 18238
# START ATG index = 18283
# START ATG index = 18307
# START ATG index = 18322
# START ATG index = 18409
# START ATG index = 18517
# START ATG index = 18601
# START ATG index = 18709
# START ATG index = 18766
# START ATG index = 18808
# START ATG index = 18829
# START ATG index = 18835
# START ATG index = 18841
# START ATG index = 18856
# START ATG index = 18940
# START ATG index = 18955
# START ATG index = 19072
# START ATG index = 19090
# START ATG index = 19093
# START ATG index = 19147
# START ATG index = 19174
# START ATG index = 19201
# START ATG index = 19282
# START ATG index = 19297
# START ATG index = 19309
# START ATG index = 19402
# START ATG index = 19432
# START ATG index = 19498
# START ATG index = 19504
# START ATG index = 19525
# START ATG index = 19630
# START ATG index = 19642
# START ATG index = 19666
# START ATG index = 19726
# START ATG index = 19735
# START ATG index = 19774
# START ATG index = 19891
# START ATG index = 19990
# START ATG index = 20002
# START ATG index = 20026
# START ATG index = 20035
# START ATG index = 20107
# START ATG index = 20167
# START ATG index = 20275
# START ATG index = 20308
# START ATG index = 20329
# START ATG index = 20464
# START ATG index = 20518
# START ATG index = 20623
# START ATG index = 20629
# START ATG index = 20746
# START ATG index = 20785
# START ATG index = 20959
# START ATG index = 20974
# START ATG index = 21070
# START ATG index = 21085
# START ATG index = 21187
# START ATG index = 21244
# START ATG index = 21250
# START ATG index = 21316
# START ATG index = 21322
# START ATG index = 21331
# START ATG index = 21460
# START ATG index = 21535
# START ATG index = 21562
# START ATG index = 22018
# START ATG index = 22090
# START ATG index = 23650
# START ATG index = 23752
# START ATG index = 23779
# START ATG index = 24166
# START ATG index = 24259
# START ATG index = 24265
# START ATG index = 24646
# START ATG index = 24709
# START ATG index = 25246
# START ATG index = 25258
# START ATG index = 25270
# START ATG index = 25456
# START ATG index = 25717
# START ATG index = 25813
# START ATG index = 25816
# START ATG index = 25909
# START ATG index = 25936
# START ATG index = 26071
# START ATG index = 26104
# START ATG index = 26119
# START ATG index = 26182
# START ATG index = 26185
# START ATG index = 26230
# START ATG index = 26578
# START ATG index = 26611
# START ATG index = 26692
# START ATG index = 27358
# START ATG index = 27949
# START ATG index = 27964
# START ATG index = 28024
# START ATG index = 28273
# START ATG index = 28573
# START ATG index = 28900
# START ATG index = 28972
# START ATG index = 29221
# START ATG index = 29236
# START ATG index = 29503
# START ATG index = 29557
# START ATG index = 29617
# START ATG index = 29770
# START ATG index = 29791
