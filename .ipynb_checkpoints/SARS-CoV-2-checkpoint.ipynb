# %%
from ajk_utils.parse_fasta import parse_fasta
from ajk_utils.orf_finder import get_orfs

# %%
# def parse_fasta(fasta_file):
#     sequence = ''
#     with open(fasta_file) as f:
#         for line in f:
#             if not line.startswith(">"):
#                 sequence += line.strip()
                
#     return sequence

# %%
# def get_genes(seq):
#     first_start = sequence.index("ATG") # stores position of first START codon
#     stop_codons = ['TAG', 'TAA', 'TGA']
#     start_positions = []
#     for i in range(first_start, len(seq), 3):
#         codon = seq[i:i+3]
#         if codon == 'ATG':
#             start_positions.append(i)
#             #print("START", codon, "index =", i)
#         #if codon in stop_codons:
#         #    print("STOP", codon, "index =", i)
                
#     return start_positions

# %%
# sequence = parse_fasta("sars_cov2.fasta")
# get_genes(sequence)

# %%
sequence = parse_fasta('sars_cov2.fasta')

# %%
#Return ORFS with length >= 150, do not show nested
# orfs = get_orfs(sequence, 150, False)
# print(*orfs, sep='\n')

# %%
#Return ORFS with length >= 90, include nested
orfs_nested = get_orfs(sequence, 90, True)
print(*orfs_nested, sep='\n')
# Out:
# (266, 13480, 2)
# (594, 683, 3)
# (726, 878, 3)
# (966, 1094, 3)
# (1605, 1736, 3)
# (1866, 1964, 3)
# (2958, 3203, 3)
# (3207, 3299, 3)
# (3612, 3749, 3)
# (3948, 4100, 3)
# (4707, 4832, 3)
# (5103, 5213, 3)
# (5919, 6086, 3)
# (6156, 6347, 3)
# (7548, 7706, 3)
# (8001, 8099, 3)
# (9099, 9191, 3)
# (9981, 10112, 3)
# (10215, 10397, 3)
# (10951, 11085, 1)
# (13311, 13463, 3)
# (13768, 21552, 1)
# (14651, 14749, 2)
# (15461, 15664, 2)
# (16166, 16276, 2)
# (16493, 16600, 2)
# (16682, 16795, 2)
# (16973, 17119, 2)
# (17606, 17713, 2)
# (18410, 18520, 2)
# (19148, 19300, 2)
# (20168, 20260, 2)
# (21536, 25381, 2)
# (21744, 21860, 3)
# (21936, 22196, 3)
# (22614, 22721, 3)
# (23403, 23510, 3)
# (23526, 23621, 3)
# (24051, 24167, 3)
# (24762, 24872, 3)
# (25195, 25284, 1)
# (25332, 25445, 3)
# (25393, 26217, 1)
# (25457, 25579, 2)
# (25524, 25694, 3)
# (25968, 26066, 3)
# (26072, 26167, 2)
# (26183, 26278, 2)
# (26245, 26469, 1)
# (26523, 27188, 3)
# (26693, 26869, 2)
# (27202, 27384, 1)
# (27394, 27756, 1)
# (27756, 27884, 3)
# (27894, 28256, 3)
# (28081, 28188, 1)
# (28274, 29530, 2)
# (28284, 28574, 3)
# (28734, 28952, 3)
# (29558, 29671, 2)

# %%
#Creating reverse complementary strand
comp_base = {'A': 'T', 'T': 'A', 'G': 'C', 'C':'G'}

seq_list = list(sequence)
seq_list.reverse()
reverse = ''.join(seq_list)

r_comp = ''.join([comp_base[i] for i in reverse])
# print(sequence[421:594])

# %%
# Return complementary ORFS with length >= 150, do not show nested
# orfs = get_orfs(r_comp, 150, False)
# comp_orfs = [((len(r_comp) - i[0]) + 1, (len(r_comp) - i[1]) + 1, i[2]) 
#             for i in orfs]
# comp_orfs.sort(key=lambda gene: (gene[0], gene[1], gene[2]))
# print(*comp_orfs, sep='\n')

# %%
#Return complementary ORFS with length >= 90, include nested
orfs = get_orfs(r_comp, 90, True)
comp_orfs_nested = [((len(r_comp) + 1 - i[1]), (len(r_comp) + 1 - i[0]), '-') 
            for i in orfs]
comp_orfs_nested.sort(key=lambda gene: (gene[0], gene[1], gene[2]))
print()
print(*comp_orfs_nested, sep='\n')
# Out:
# (13, 108, '-')
# (425, 667, '-')
# (519, 692, '-')
# (1012, 1104, '-')
# (1394, 1570, '-')
# (1531, 1689, '-')
# (2293, 2457, '-')
# (2845, 2949, '-')
# (3362, 3466, '-')
# (4327, 4458, '-')
# (4876, 5022, '-')
# (5476, 5577, '-')
# (5690, 5779, '-')
# (6190, 6489, '-')
# (7235, 7336, '-')
# (7324, 7419, '-')
# (7691, 7825, '-')
# (8240, 8359, '-')
# (8800, 8949, '-')
# (9398, 9493, '-')
# (10043, 10177, '-')
# (10276, 10371, '-')
# (10758, 10856, '-')
# (11935, 12045, '-')
# (12157, 12255, '-')
# (12286, 12486, '-')
# (13118, 13273, '-')
# (13362, 13550, '-')
# (13908, 14027, '-')
# (13913, 14059, '-')
# (14995, 15156, '-')
# (15569, 15682, '-')
# (15793, 15888, '-')
# (16203, 16295, '-')
# (16211, 16306, '-')
# (16802, 16939, '-')
# (17014, 17106, '-')
# (17448, 17543, '-')
# (17509, 17628, '-')
# (17982, 18185, '-')
# (18154, 18324, '-')
# (19716, 19856, '-')
# (19768, 19905, '-')
# (20847, 21038, '-')
# (23077, 23322, '-')
# (23201, 23437, '-')
# (23683, 23787, '-')
# (23929, 24111, '-')
# (25102, 25242, '-')
# (25589, 25807, '-')
# (26184, 26342, '-')
# (26807, 27004, '-')
# (27037, 27210, '-')
# (27643, 27771, '-')
# (28731, 28835, '-')
# (29210, 29341, '-')
# (29413, 29505, '-')
# (29688, 29840, '-')

# %%
#Print all genes
gene_list = [(i[0], i[1], '+') for i in orfs_nested]
gene_list.extend(comp_orfs_nested)
gene_list.sort(key=lambda gene: (gene[0], gene[1], gene[2]))

print('\n'.join([f'Gene {i + 1}: {gene_list[i]}' 
               for i in range(len(gene_list))]))
# Out:
# Gene 1: (13, 108, '-')
# Gene 2: (266, 13480, '+')
# Gene 3: (425, 667, '-')
# Gene 4: (519, 692, '-')
# Gene 5: (594, 683, '+')
# Gene 6: (726, 878, '+')
# Gene 7: (966, 1094, '+')
# Gene 8: (1012, 1104, '-')
# Gene 9: (1394, 1570, '-')
# Gene 10: (1531, 1689, '-')
# Gene 11: (1605, 1736, '+')
# Gene 12: (1866, 1964, '+')
# Gene 13: (2293, 2457, '-')
# Gene 14: (2845, 2949, '-')
# Gene 15: (2958, 3203, '+')
# Gene 16: (3207, 3299, '+')
# Gene 17: (3362, 3466, '-')
# Gene 18: (3612, 3749, '+')
# Gene 19: (3948, 4100, '+')
# Gene 20: (4327, 4458, '-')
# Gene 21: (4707, 4832, '+')
# Gene 22: (4876, 5022, '-')
# Gene 23: (5103, 5213, '+')
# Gene 24: (5476, 5577, '-')
# Gene 25: (5690, 5779, '-')
# Gene 26: (5919, 6086, '+')
# Gene 27: (6156, 6347, '+')
# Gene 28: (6190, 6489, '-')
# Gene 29: (7235, 7336, '-')
# Gene 30: (7324, 7419, '-')
# Gene 31: (7548, 7706, '+')
# Gene 32: (7691, 7825, '-')
# Gene 33: (8001, 8099, '+')
# Gene 34: (8240, 8359, '-')
# Gene 35: (8800, 8949, '-')
# Gene 36: (9099, 9191, '+')
# Gene 37: (9398, 9493, '-')
# Gene 38: (9981, 10112, '+')
# Gene 39: (10043, 10177, '-')
# Gene 40: (10215, 10397, '+')
# Gene 41: (10276, 10371, '-')
# Gene 42: (10758, 10856, '-')
# Gene 43: (10951, 11085, '+')
# Gene 44: (11935, 12045, '-')
# Gene 45: (12157, 12255, '-')
# Gene 46: (12286, 12486, '-')
# Gene 47: (13118, 13273, '-')
# Gene 48: (13311, 13463, '+')
# Gene 49: (13362, 13550, '-')
# Gene 50: (13768, 21552, '+')
# Gene 51: (13908, 14027, '-')
# Gene 52: (13913, 14059, '-')
# Gene 53: (14651, 14749, '+')
# Gene 54: (14995, 15156, '-')
# Gene 55: (15461, 15664, '+')
# Gene 56: (15569, 15682, '-')
# Gene 57: (15793, 15888, '-')
# Gene 58: (16166, 16276, '+')
# Gene 59: (16203, 16295, '-')
# Gene 60: (16211, 16306, '-')
# Gene 61: (16493, 16600, '+')
# Gene 62: (16682, 16795, '+')
# Gene 63: (16802, 16939, '-')
# Gene 64: (16973, 17119, '+')
# Gene 65: (17014, 17106, '-')
# Gene 66: (17448, 17543, '-')
# Gene 67: (17509, 17628, '-')
# Gene 68: (17606, 17713, '+')
# Gene 69: (17982, 18185, '-')
# Gene 70: (18154, 18324, '-')
# Gene 71: (18410, 18520, '+')
# Gene 72: (19148, 19300, '+')
# Gene 73: (19716, 19856, '-')
# Gene 74: (19768, 19905, '-')
# Gene 75: (20168, 20260, '+')
# Gene 76: (20847, 21038, '-')
# Gene 77: (21536, 25381, '+')
# Gene 78: (21744, 21860, '+')
# Gene 79: (21936, 22196, '+')
# Gene 80: (22614, 22721, '+')
# Gene 81: (23077, 23322, '-')
# Gene 82: (23201, 23437, '-')
# Gene 83: (23403, 23510, '+')
# Gene 84: (23526, 23621, '+')
# Gene 85: (23683, 23787, '-')
# Gene 86: (23929, 24111, '-')
# Gene 87: (24051, 24167, '+')
# Gene 88: (24762, 24872, '+')
# Gene 89: (25102, 25242, '-')
# Gene 90: (25195, 25284, '+')
# Gene 91: (25332, 25445, '+')
# Gene 92: (25393, 26217, '+')
# Gene 93: (25457, 25579, '+')
# Gene 94: (25524, 25694, '+')
# Gene 95: (25589, 25807, '-')
# Gene 96: (25968, 26066, '+')
# Gene 97: (26072, 26167, '+')
# Gene 98: (26183, 26278, '+')
# Gene 99: (26184, 26342, '-')
# Gene 100: (26245, 26469, '+')
# Gene 101: (26523, 27188, '+')
# Gene 102: (26693, 26869, '+')
# Gene 103: (26807, 27004, '-')
# Gene 104: (27037, 27210, '-')
# Gene 105: (27202, 27384, '+')
# Gene 106: (27394, 27756, '+')
# Gene 107: (27643, 27771, '-')
# Gene 108: (27756, 27884, '+')
# Gene 109: (27894, 28256, '+')
# Gene 110: (28081, 28188, '+')
# Gene 111: (28274, 29530, '+')
# Gene 112: (28284, 28574, '+')
# Gene 113: (28731, 28835, '-')
# Gene 114: (28734, 28952, '+')
# Gene 115: (29210, 29341, '-')
# Gene 116: (29413, 29505, '-')
# Gene 117: (29558, 29671, '+')
# Gene 118: (29688, 29840, '-')
